# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir('/Users/owner/Documents/WC_DS')
df = pd.read_csv('dhs_service_records_synthesized_final.csv')

# %%
service_attributes_total = df.groupby('service').count().sort_values(by="service", ascending=False)
service_attributes_total
# Out:
#                                                     synthetic_data  \
# service
# Suicides                                                      1177
# Parents_Receiving_Child_Welfare_Services                     54035
# Overdoses                                                     1319
# Older_Adults_Receiving_Services                             131153
# Mental_Health_Crises                                          7245
# Jail_Population                                              26987
# Involuntary_Commitments                                       7061
# Individuals_Receiving_Substance_Use_Disorder_Se...           74737
# Individuals_Receiving_Mental_Health_Services                324241
# Individuals_Receiving_Intellectual_Disability_S...           74145
# Individuals_Receiving_Income_Supports                      5450993
# Individuals_Receiving_Homelessness_and_Housing_...          148968
# Individuals_Receiving_Family_Strengthening_Prog...           28110
# ...

# %%
service_attributes_month = df.groupby('DATE_OF_EVENT').count().sort_values(by="MCI_UNIQ_ID", ascending=False)
service_attributes_month
# Out:
#                synthetic_data  MCI_UNIQ_ID  CALDR_YR  service  GEO_AREA  \
# DATE_OF_EVENT
# 11/30/2021             608114       608114    608114   608114         0
# 10/31/2021             605740       605740    605740   605740         0
# 09/30/2021             605237       605237    605237   605237         0
# 12/31/2021             604093       604093    604093   604093         0
# 08/31/2021             597912       597912    597912   597912         0
# 07/31/2021             593599       593599    593599   593599         0
# 06/30/2021             590825       590825    590825   590825         0
# 04/30/2021             589976       589976    589976   589976         0
# 05/31/2021             586749       586749    586749   586749         0
# 03/31/2021             585761       585761    585761   585761         0
# 02/28/2021             576907       576907    576907   576907         0
# 01/31/2021             571221       571221    571221   571221         0
#
# ...

# %%
## CONCLUSIONS
#We can conclude that less people are using government services at the beginning of the year than the end of the year.
